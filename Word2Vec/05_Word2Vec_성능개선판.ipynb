# %% [markdown]
# ## 성능 개선판 word2vec 학습모델 구현

# %% [markdown]
# ### CBOW 모델 구현

# %%
from nn_layers import  Embedding, EmbeddingDot, NegativeSamplingLoss, Adam, Trainer
from mynlp import  preprocess, most_similar, create_contexts_target 
import numpy as np

# %%
class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embedding 계층 사용
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %% [markdown]
# ### CBOW 모델 학습 코드

# %%
from dataset import ptb
import pickle

# 하이퍼파라미터 설정
window_size = 5
# window_size = 2

hidden_size = 100
batch_size = 100
max_epoch = 10  # 10회 이상

# 데이터 읽기
# 전체 데이터 모두 사용시
# corpus, word_to_id, id_to_word = ptb.load_data('train')

# vocab_size = len(word_to_id)
# print(vocab_size)
# print(len(word_to_id))
# print(len(corpus))

# %%
# PTB 데이터 중 일부만 사용시
corpus, word_to_id, id_to_word = ptb.load_data('train')

corpus_size = 10000
corpus = corpus[:corpus_size]

vocab_size = int(max(corpus) + 1)

temp1,temp2 = {},{}
for k in range(vocab_size):
    word1= list(word_to_id.keys())[k]    
    id1 = list(word_to_id.values())[k] 
    temp1[word1] = id1
    
    word2= list(id_to_word.keys())[k]    
    id2 = list(id_to_word.values())[k] 
    temp2[word2] = id2
    
word_to_id = temp1
id_to_word =temp2

print(len(corpus))
print(vocab_size)
print(len(word_to_id))
print(len(id_to_word))
# Out:
# 100000
# 6932
# 6932
# 6932

# %%
contexts, target = create_contexts_target(corpus, window_size)


# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs

params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 999 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 999 | 시간 1[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 999 | 시간 2[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 999 | 시간 3[s] | 손실 4.11
# | 에폭 1 |  반복 81 / 999 | 시간 4[s] | 손실 4.02
# | 에폭 1 |  반복 101 / 999 | 시간 5[s] | 손실 3.88
# | 에폭 1 |  반복 121 / 999 | 시간 6[s] | 손실 3.71
# | 에폭 1 |  반복 141 / 999 | 시간 7[s] | 손실 3.55
# | 에폭 1 |  반복 161 / 999 | 시간 8[s] | 손실 3.40
# | 에폭 1 |  반복 181 / 999 | 시간 9[s] | 손실 3.26
# | 에폭 1 |  반복 201 / 999 | 시간 10[s] | 손실 3.15
# | 에폭 1 |  반복 221 / 999 | 시간 11[s] | 손실 3.08
# | 에폭 1 |  반복 241 / 999 | 시간 12[s] | 손실 2.99
# | 에폭 1 |  반복 261 / 999 | 시간 13[s] | 손실 2.92
# | 에폭 1 |  반복 281 / 999 | 시간 14[s] | 손실 2.89
# | 에폭 1 |  반복 301 / 999 | 시간 16[s] | 손실 2.83
# | 에폭 1 |  반복 321 / 999 | 시간 17[s] | 손실 2.84
# | 에폭 1 |  반복 341 / 999 | 시간 18[s] | 손실 2.79
# | 에폭 1 |  반복 361 / 999 | 시간 19[s] | 손실 2.77
# | 에폭 1 |  반복 381 / 999 | 시간 20[s] | 손실 2.75
# | 에폭 1 |  반복 401 / 999 | 시간 21[s] | 손실 2.73
# | 에폭 1 |  반복 421 / 999 | 시간 22[s] | 손실 2.71
# | 에폭 1 |  반복 441 / 999 | 시간 23[s] | 손실 2.69
# | 에폭 1 |  반복 461 / 999 | 시간 24[s] | 손실 2.67
# | 에폭 1 |  반복 481 / 999 | 시간 25[s] | 손실 2.68
# | 에폭 1 |  반복 501 / 999 | 시간 26[s] | 손실 2.68
# | 에폭 1 |  반복 521 / 999 | 시간 27[s] | 손실 2.67
# | 에폭 1 |  반복 541 / 999 | 시간 28[s] | 손실 2.64
# | 에폭 1 |  반복 561 / 999 | 시간 29[s] | 손실 2.67
# | 에폭 1 |  반복 581 / 999 | 시간 30[s] | 손실 2.64
# | 에폭 1 |  반복 601 / 999 | 시간 32[s] | 손실 2.63
# | 에폭 1 |  반복 621 / 999 | 시간 33[s] | 손실 2.64
# | 에폭 1 |  반복 641 / 999 | 시간 34[s] | 손실 2.64
# | 에폭 1 |  반복 661 / 999 | 시간 35[s] | 손실 2.63
# | 에폭 1 |  반복 681 / 999 | 시간 36[s] | 손실 2.62
# | 에폭 1 |  반복 701 / 999 | 시간 37[s] | 손실 2.62
# | 에폭 1 |  반복 721 / 999 | 시간 38[s] | 손실 2.62
# | 에폭 1 |  반복 741 / 999 | 시간 39[s] | 손실 2.64
# | 에폭 1 |  반복 761 / 999 | 시간 40[s] | 손실 2.60
# | 에폭 1 |  반복 781 / 999 | 시간 41[s] | 손실 2.60
# | 에폭 1 |  반복 801 / 999 | 시간 42[s] | 손실 2.58
# | 에폭 1 |  반복 821 / 999 | 시간 43[s] | 손실 2.61
# | 에폭 1 |  반복 841 / 999 | 시간 44[s] | 손실 2.63
# | 에폭 1 |  반복 861 / 999 | 시간 45[s] | 손실 2.61
# | 에폭 1 |  반복 881 / 999 | 시간 46[s] | 손실 2.60
# | 에폭 1 |  반복 901 / 999 | 시간 47[s] | 손실 2.60
# | 에폭 1 |  반복 921 / 999 | 시간 48[s] | 손실 2.60
# | 에폭 1 |  반복 941 / 999 | 시간 49[s] | 손실 2.57
# | 에폭 1 |  반복 961 / 999 | 시간 50[s] | 손실 2.60
# | 에폭 1 |  반복 981 / 999 | 시간 51[s] | 손실 2.57
# | 에폭 2 |  반복 1 / 999 | 시간 52[s] | 손실 2.61
# | 에폭 2 |  반복 21 / 999 | 시간 53[s] | 손실 2.57
# | 에폭 2 |  반복 41 / 999 | 시간 55[s] | 손실 2.56
# | 에폭 2 |  반복 61 / 999 | 시간 56[s] | 손실 2.54
# | 에폭 2 |  반복 81 / 999 | 시간 57[s] | 손실 2.52
# | 에폭 2 |  반복 101 / 999 | 시간 58[s] | 손실 2.52
# | 에폭 2 |  반복 121 / 999 | 시간 59[s] | 손실 2.55
# | 에폭 2 |  반복 141 / 999 | 시간 60[s] | 손실 2.54
# | 에폭 2 |  반복 161 / 999 | 시간 61[s] | 손실 2.53
# | 에폭 2 |  반복 181 / 999 | 시간 62[s] | 손실 2.54
# | 에폭 2 |  반복 201 / 999 | 시간 63[s] | 손실 2.55
# | 에폭 2 |  반복 221 / 999 | 시간 64[s] | 손실 2.56
# | 에폭 2 |  반복 241 / 999 | 시간 65[s] | 손실 2.51
# | 에폭 2 |  반복 261 / 999 | 시간 67[s] | 손실 2.55
# | 에폭 2 |  반복 281 / 999 | 시간 68[s] | 손실 2.55
# | 에폭 2 |  반복 301 / 999 | 시간 69[s] | 손실 2.55
# | 에폭 2 |  반복 321 / 999 | 시간 70[s] | 손실 2.54
# | 에폭 2 |  반복 341 / 999 | 시간 71[s] | 손실 2.54
# | 에폭 2 |  반복 361 / 999 | 시간 72[s] | 손실 2.54
# | 에폭 2 |  반복 381 / 999 | 시간 73[s] | 손실 2.55
# | 에폭 2 |  반복 401 / 999 | 시간 74[s] | 손실 2.53
# | 에폭 2 |  반복 421 / 999 | 시간 75[s] | 손실 2.52
# | 에폭 2 |  반복 441 / 999 | 시간 76[s] | 손실 2.54
# | 에폭 2 |  반복 461 / 999 | 시간 78[s] | 손실 2.52
# | 에폭 2 |  반복 481 / 999 | 시간 79[s] | 손실 2.55
# | 에폭 2 |  반복 501 / 999 | 시간 80[s] | 손실 2.50
# | 에폭 2 |  반복 521 / 999 | 시간 81[s] | 손실 2.54
# | 에폭 2 |  반복 541 / 999 | 시간 82[s] | 손실 2.52
# | 에폭 2 |  반복 561 / 999 | 시간 83[s] | 손실 2.56
# | 에폭 2 |  반복 581 / 999 | 시간 84[s] | 손실 2.52
# | 에폭 2 |  반복 601 / 999 | 시간 85[s] | 손실 2.55
# | 에폭 2 |  반복 621 / 999 | 시간 86[s] | 손실 2.53
# | 에폭 2 |  반복 641 / 999 | 시간 87[s] | 손실 2.50
# | 에폭 2 |  반복 661 / 999 | 시간 88[s] | 손실 2.54
# | 에폭 2 |  반복 681 / 999 | 시간 89[s] | 손실 2.53
# | 에폭 2 |  반복 701 / 999 | 시간 90[s] | 손실 2.52
# | 에폭 2 |  반복 721 / 999 | 시간 91[s] | 손실 2.52
# | 에폭 2 |  반복 741 / 999 | 시간 92[s] | 손실 2.51
# | 에폭 2 |  반복 761 / 999 | 시간 93[s] | 손실 2.51
# | 에폭 2 |  반복 781 / 999 | 시간 94[s] | 손실 2.52
# | 에폭 2 |  반복 801 / 999 | 시간 95[s] | 손실 2.50
# | 에폭 2 |  반복 821 / 999 | 시간 96[s] | 손실 2.53
# | 에폭 2 |  반복 841 / 999 | 시간 97[s] | 손실 2.51
# | 에폭 2 |  반복 861 / 999 | 시간 98[s] | 손실 2.53
# | 에폭 2 |  반복 881 / 999 | 시간 100[s] | 손실 2.52
# | 에폭 2 |  반복 901 / 999 | 시간 101[s] | 손실 2.54
# | 에폭 2 |  반복 921 / 999 | 시간 102[s] | 손실 2.50
# | 에폭 2 |  반복 941 / 999 | 시간 103[s] | 손실 2.55
# | 에폭 2 |  반복 961 / 999 | 시간 104[s] | 손실 2.53
# | 에폭 2 |  반복 981 / 999 | 시간 105[s] | 손실 2.55
# | 에폭 3 |  반복 1 / 999 | 시간 106[s] | 손실 2.50
# | 에폭 3 |  반복 21 / 999 | 시간 107[s] | 손실 2.45
# | 에폭 3 |  반복 41 / 999 | 시간 108[s] | 손실 2.46
# | 에폭 3 |  반복 61 / 999 | 시간 109[s] | 손실 2.49
# | 에폭 3 |  반복 81 / 999 | 시간 110[s] | 손실 2.46
# | 에폭 3 |  반복 101 / 999 | 시간 111[s] | 손실 2.47
# | 에폭 3 |  반복 121 / 999 | 시간 112[s] | 손실 2.48
# | 에폭 3 |  반복 141 / 999 | 시간 113[s] | 손실 2.49
# | 에폭 3 |  반복 161 / 999 | 시간 114[s] | 손실 2.48
# | 에폭 3 |  반복 181 / 999 | 시간 115[s] | 손실 2.49
# | 에폭 3 |  반복 201 / 999 | 시간 116[s] | 손실 2.47
# | 에폭 3 |  반복 221 / 999 | 시간 117[s] | 손실 2.48
# | 에폭 3 |  반복 241 / 999 | 시간 118[s] | 손실 2.46
# | 에폭 3 |  반복 261 / 999 | 시간 119[s] | 손실 2.46
# | 에폭 3 |  반복 281 / 999 | 시간 120[s] | 손실 2.49
# | 에폭 3 |  반복 301 / 999 | 시간 121[s] | 손실 2.49
# | 에폭 3 |  반복 321 / 999 | 시간 122[s] | 손실 2.49
# | 에폭 3 |  반복 341 / 999 | 시간 123[s] | 손실 2.52
# | 에폭 3 |  반복 361 / 999 | 시간 124[s] | 손실 2.48
# | 에폭 3 |  반복 381 / 999 | 시간 125[s] | 손실 2.48
# | 에폭 3 |  반복 401 / 999 | 시간 126[s] | 손실 2.47
# | 에폭 3 |  반복 421 / 999 | 시간 127[s] | 손실 2.47
# | 에폭 3 |  반복 441 / 999 | 시간 128[s] | 손실 2.47
# | 에폭 3 |  반복 461 / 999 | 시간 130[s] | 손실 2.50
# | 에폭 3 |  반복 481 / 999 | 시간 131[s] | 손실 2.48
# | 에폭 3 |  반복 501 / 999 | 시간 132[s] | 손실 2.47
# | 에폭 3 |  반복 521 / 999 | 시간 133[s] | 손실 2.47
# | 에폭 3 |  반복 541 / 999 | 시간 134[s] | 손실 2.46
# | 에폭 3 |  반복 561 / 999 | 시간 135[s] | 손실 2.46
# | 에폭 3 |  반복 581 / 999 | 시간 136[s] | 손실 2.46
# | 에폭 3 |  반복 601 / 999 | 시간 137[s] | 손실 2.48
# | 에폭 3 |  반복 621 / 999 | 시간 138[s] | 손실 2.48
# | 에폭 3 |  반복 641 / 999 | 시간 139[s] | 손실 2.47
# | 에폭 3 |  반복 661 / 999 | 시간 140[s] | 손실 2.46
# | 에폭 3 |  반복 681 / 999 | 시간 141[s] | 손실 2.47
# | 에폭 3 |  반복 701 / 999 | 시간 142[s] | 손실 2.47
# | 에폭 3 |  반복 721 / 999 | 시간 143[s] | 손실 2.46
# | 에폭 3 |  반복 741 / 999 | 시간 144[s] | 손실 2.50
# | 에폭 3 |  반복 761 / 999 | 시간 145[s] | 손실 2.46
# | 에폭 3 |  반복 781 / 999 | 시간 146[s] | 손실 2.47
# | 에폭 3 |  반복 801 / 999 | 시간 147[s] | 손실 2.51
# | 에폭 3 |  반복 821 / 999 | 시간 148[s] | 손실 2.48
# | 에폭 3 |  반복 841 / 999 | 시간 149[s] | 손실 2.46
# | 에폭 3 |  반복 861 / 999 | 시간 150[s] | 손실 2.46
# | 에폭 3 |  반복 881 / 999 | 시간 151[s] | 손실 2.51
# | 에폭 3 |  반복 901 / 999 | 시간 152[s] | 손실 2.48
# | 에폭 3 |  반복 921 / 999 | 시간 153[s] | 손실 2.46
# | 에폭 3 |  반복 941 / 999 | 시간 154[s] | 손실 2.47
# | 에폭 3 |  반복 961 / 999 | 시간 155[s] | 손실 2.46
# | 에폭 3 |  반복 981 / 999 | 시간 156[s] | 손실 2.46
# | 에폭 4 |  반복 1 / 999 | 시간 157[s] | 손실 2.47
# | 에폭 4 |  반복 21 / 999 | 시간 158[s] | 손실 2.41
# | 에폭 4 |  반복 41 / 999 | 시간 160[s] | 손실 2.41
# | 에폭 4 |  반복 61 / 999 | 시간 161[s] | 손실 2.41
# | 에폭 4 |  반복 81 / 999 | 시간 162[s] | 손실 2.43
# | 에폭 4 |  반복 101 / 999 | 시간 163[s] | 손실 2.43
# | 에폭 4 |  반복 121 / 999 | 시간 164[s] | 손실 2.42
# | 에폭 4 |  반복 141 / 999 | 시간 165[s] | 손실 2.39
# | 에폭 4 |  반복 161 / 999 | 시간 166[s] | 손실 2.43
# | 에폭 4 |  반복 181 / 999 | 시간 167[s] | 손실 2.40
# | 에폭 4 |  반복 201 / 999 | 시간 168[s] | 손실 2.44
# | 에폭 4 |  반복 221 / 999 | 시간 169[s] | 손실 2.40
# | 에폭 4 |  반복 241 / 999 | 시간 170[s] | 손실 2.39
# | 에폭 4 |  반복 261 / 999 | 시간 171[s] | 손실 2.42
# | 에폭 4 |  반복 281 / 999 | 시간 172[s] | 손실 2.42
# | 에폭 4 |  반복 301 / 999 | 시간 173[s] | 손실 2.41
# | 에폭 4 |  반복 321 / 999 | 시간 174[s] | 손실 2.39
# | 에폭 4 |  반복 341 / 999 | 시간 175[s] | 손실 2.41
# | 에폭 4 |  반복 361 / 999 | 시간 176[s] | 손실 2.42
# | 에폭 4 |  반복 381 / 999 | 시간 177[s] | 손실 2.42
# | 에폭 4 |  반복 401 / 999 | 시간 178[s] | 손실 2.44
# | 에폭 4 |  반복 421 / 999 | 시간 179[s] | 손실 2.41
# | 에폭 4 |  반복 441 / 999 | 시간 180[s] | 손실 2.41
# | 에폭 4 |  반복 461 / 999 | 시간 181[s] | 손실 2.40
# | 에폭 4 |  반복 481 / 999 | 시간 182[s] | 손실 2.42
# | 에폭 4 |  반복 501 / 999 | 시간 183[s] | 손실 2.40
# | 에폭 4 |  반복 521 / 999 | 시간 184[s] | 손실 2.42
# | 에폭 4 |  반복 541 / 999 | 시간 185[s] | 손실 2.40
# | 에폭 4 |  반복 561 / 999 | 시간 187[s] | 손실 2.40
# | 에폭 4 |  반복 581 / 999 | 시간 188[s] | 손실 2.39
# | 에폭 4 |  반복 601 / 999 | 시간 189[s] | 손실 2.40
# | 에폭 4 |  반복 621 / 999 | 시간 190[s] | 손실 2.40
# | 에폭 4 |  반복 641 / 999 | 시간 191[s] | 손실 2.41
# | 에폭 4 |  반복 661 / 999 | 시간 192[s] | 손실 2.41
# | 에폭 4 |  반복 681 / 999 | 시간 193[s] | 손실 2.43
# | 에폭 4 |  반복 701 / 999 | 시간 194[s] | 손실 2.39
# | 에폭 4 |  반복 721 / 999 | 시간 195[s] | 손실 2.41
# | 에폭 4 |  반복 741 / 999 | 시간 196[s] | 손실 2.40
# | 에폭 4 |  반복 761 / 999 | 시간 197[s] | 손실 2.41
# | 에폭 4 |  반복 781 / 999 | 시간 198[s] | 손실 2.40
# | 에폭 4 |  반복 801 / 999 | 시간 199[s] | 손실 2.39
# | 에폭 4 |  반복 821 / 999 | 시간 200[s] | 손실 2.39
# | 에폭 4 |  반복 841 / 999 | 시간 201[s] | 손실 2.38
# | 에폭 4 |  반복 861 / 999 | 시간 202[s] | 손실 2.39
# | 에폭 4 |  반복 881 / 999 | 시간 203[s] | 손실 2.40
# | 에폭 4 |  반복 901 / 999 | 시간 204[s] | 손실 2.42
# | 에폭 4 |  반복 921 / 999 | 시간 205[s] | 손실 2.41
# | 에폭 4 |  반복 941 / 999 | 시간 206[s] | 손실 2.40
# | 에폭 4 |  반복 961 / 999 | 시간 207[s] | 손실 2.38
# | 에폭 4 |  반복 981 / 999 | 시간 208[s] | 손실 2.38
# | 에폭 5 |  반복 1 / 999 | 시간 209[s] | 손실 2.40
# | 에폭 5 |  반복 21 / 999 | 시간 210[s] | 손실 2.33
# | 에폭 5 |  반복 41 / 999 | 시간 211[s] | 손실 2.36
# | 에폭 5 |  반복 61 / 999 | 시간 212[s] | 손실 2.35
# | 에폭 5 |  반복 81 / 999 | 시간 213[s] | 손실 2.36
# | 에폭 5 |  반복 101 / 999 | 시간 215[s] | 손실 2.34
# | 에폭 5 |  반복 121 / 999 | 시간 216[s] | 손실 2.33
# | 에폭 5 |  반복 141 / 999 | 시간 217[s] | 손실 2.34
# | 에폭 5 |  반복 161 / 999 | 시간 218[s] | 손실 2.32
# | 에폭 5 |  반복 181 / 999 | 시간 219[s] | 손실 2.36
# | 에폭 5 |  반복 201 / 999 | 시간 220[s] | 손실 2.33
# | 에폭 5 |  반복 221 / 999 | 시간 221[s] | 손실 2.35
# | 에폭 5 |  반복 241 / 999 | 시간 222[s] | 손실 2.33
# | 에폭 5 |  반복 261 / 999 | 시간 223[s] | 손실 2.32
# | 에폭 5 |  반복 281 / 999 | 시간 224[s] | 손실 2.32
# | 에폭 5 |  반복 301 / 999 | 시간 225[s] | 손실 2.32
# | 에폭 5 |  반복 321 / 999 | 시간 226[s] | 손실 2.34
# | 에폭 5 |  반복 341 / 999 | 시간 227[s] | 손실 2.31
# | 에폭 5 |  반복 361 / 999 | 시간 228[s] | 손실 2.34
# | 에폭 5 |  반복 381 / 999 | 시간 229[s] | 손실 2.30
# | 에폭 5 |  반복 401 / 999 | 시간 230[s] | 손실 2.34
# | 에폭 5 |  반복 421 / 999 | 시간 231[s] | 손실 2.33
# | 에폭 5 |  반복 441 / 999 | 시간 232[s] | 손실 2.31
# | 에폭 5 |  반복 461 / 999 | 시간 233[s] | 손실 2.33
# | 에폭 5 |  반복 481 / 999 | 시간 234[s] | 손실 2.34
# | 에폭 5 |  반복 501 / 999 | 시간 235[s] | 손실 2.32
# | 에폭 5 |  반복 521 / 999 | 시간 236[s] | 손실 2.32
# | 에폭 5 |  반복 541 / 999 | 시간 237[s] | 손실 2.34
# | 에폭 5 |  반복 561 / 999 | 시간 238[s] | 손실 2.33
# | 에폭 5 |  반복 581 / 999 | 시간 239[s] | 손실 2.33
# | 에폭 5 |  반복 601 / 999 | 시간 240[s] | 손실 2.32
# | 에폭 5 |  반복 621 / 999 | 시간 242[s] | 손실 2.33
# | 에폭 5 |  반복 641 / 999 | 시간 243[s] | 손실 2.29
# | 에폭 5 |  반복 661 / 999 | 시간 244[s] | 손실 2.36
# | 에폭 5 |  반복 681 / 999 | 시간 245[s] | 손실 2.33
# | 에폭 5 |  반복 701 / 999 | 시간 246[s] | 손실 2.30
# | 에폭 5 |  반복 721 / 999 | 시간 247[s] | 손실 2.34
# | 에폭 5 |  반복 741 / 999 | 시간 248[s] | 손실 2.32
# | 에폭 5 |  반복 761 / 999 | 시간 249[s] | 손실 2.31
# | 에폭 5 |  반복 781 / 999 | 시간 250[s] | 손실 2.31
# | 에폭 5 |  반복 801 / 999 | 시간 251[s] | 손실 2.32
# | 에폭 5 |  반복 821 / 999 | 시간 252[s] | 손실 2.33
# | 에폭 5 |  반복 841 / 999 | 시간 253[s] | 손실 2.29
# | 에폭 5 |  반복 861 / 999 | 시간 254[s] | 손실 2.30
# | 에폭 5 |  반복 881 / 999 | 시간 255[s] | 손실 2.33
# | 에폭 5 |  반복 901 / 999 | 시간 256[s] | 손실 2.33
# | 에폭 5 |  반복 921 / 999 | 시간 257[s] | 손실 2.32
# | 에폭 5 |  반복 941 / 999 | 시간 258[s] | 손실 2.33
# | 에폭 5 |  반복 961 / 999 | 시간 259[s] | 손실 2.30
# | 에폭 5 |  반복 981 / 999 | 시간 260[s] | 손실 2.32
# | 에폭 6 |  반복 1 / 999 | 시간 261[s] | 손실 2.32
# | 에폭 6 |  반복 21 / 999 | 시간 262[s] | 손실 2.23
# | 에폭 6 |  반복 41 / 999 | 시간 263[s] | 손실 2.23
# | 에폭 6 |  반복 61 / 999 | 시간 264[s] | 손실 2.26
# | 에폭 6 |  반복 81 / 999 | 시간 265[s] | 손실 2.27
# | 에폭 6 |  반복 101 / 999 | 시간 266[s] | 손실 2.24
# | 에폭 6 |  반복 121 / 999 | 시간 267[s] | 손실 2.28
# | 에폭 6 |  반복 141 / 999 | 시간 268[s] | 손실 2.24
# | 에폭 6 |  반복 161 / 999 | 시간 269[s] | 손실 2.24
# | 에폭 6 |  반복 181 / 999 | 시간 271[s] | 손실 2.25
# | 에폭 6 |  반복 201 / 999 | 시간 272[s] | 손실 2.27
# | 에폭 6 |  반복 221 / 999 | 시간 273[s] | 손실 2.26
# | 에폭 6 |  반복 241 / 999 | 시간 274[s] | 손실 2.26
# | 에폭 6 |  반복 261 / 999 | 시간 275[s] | 손실 2.26
# | 에폭 6 |  반복 281 / 999 | 시간 276[s] | 손실 2.28
# | 에폭 6 |  반복 301 / 999 | 시간 277[s] | 손실 2.25
# | 에폭 6 |  반복 321 / 999 | 시간 278[s] | 손실 2.24
# | 에폭 6 |  반복 341 / 999 | 시간 279[s] | 손실 2.24
# | 에폭 6 |  반복 361 / 999 | 시간 280[s] | 손실 2.21
# | 에폭 6 |  반복 381 / 999 | 시간 281[s] | 손실 2.26
# | 에폭 6 |  반복 401 / 999 | 시간 282[s] | 손실 2.24
# | 에폭 6 |  반복 421 / 999 | 시간 283[s] | 손실 2.25
# | 에폭 6 |  반복 441 / 999 | 시간 284[s] | 손실 2.25
# | 에폭 6 |  반복 461 / 999 | 시간 285[s] | 손실 2.23
# | 에폭 6 |  반복 481 / 999 | 시간 286[s] | 손실 2.27
# | 에폭 6 |  반복 501 / 999 | 시간 287[s] | 손실 2.23
# | 에폭 6 |  반복 521 / 999 | 시간 288[s] | 손실 2.23
# | 에폭 6 |  반복 541 / 999 | 시간 289[s] | 손실 2.24
# | 에폭 6 |  반복 561 / 999 | 시간 290[s] | 손실 2.23
# | 에폭 6 |  반복 581 / 999 | 시간 291[s] | 손실 2.23
# | 에폭 6 |  반복 601 / 999 | 시간 292[s] | 손실 2.27
# | 에폭 6 |  반복 621 / 999 | 시간 293[s] | 손실 2.25
# | 에폭 6 |  반복 641 / 999 | 시간 294[s] | 손실 2.24
# | 에폭 6 |  반복 661 / 999 | 시간 295[s] | 손실 2.22
# | 에폭 6 |  반복 681 / 999 | 시간 296[s] | 손실 2.23
# | 에폭 6 |  반복 701 / 999 | 시간 297[s] | 손실 2.24
# | 에폭 6 |  반복 721 / 999 | 시간 299[s] | 손실 2.23
# | 에폭 6 |  반복 741 / 999 | 시간 300[s] | 손실 2.24
# | 에폭 6 |  반복 761 / 999 | 시간 301[s] | 손실 2.26
# | 에폭 6 |  반복 781 / 999 | 시간 302[s] | 손실 2.24
# | 에폭 6 |  반복 801 / 999 | 시간 303[s] | 손실 2.24
# | 에폭 6 |  반복 821 / 999 | 시간 304[s] | 손실 2.25
# | 에폭 6 |  반복 841 / 999 | 시간 305[s] | 손실 2.25
# | 에폭 6 |  반복 861 / 999 | 시간 306[s] | 손실 2.23
# | 에폭 6 |  반복 881 / 999 | 시간 307[s] | 손실 2.24
# | 에폭 6 |  반복 901 / 999 | 시간 308[s] | 손실 2.21
# | 에폭 6 |  반복 921 / 999 | 시간 309[s] | 손실 2.27
# | 에폭 6 |  반복 941 / 999 | 시간 310[s] | 손실 2.24
# | 에폭 6 |  반복 961 / 999 | 시간 311[s] | 손실 2.22
# | 에폭 6 |  반복 981 / 999 | 시간 312[s] | 손실 2.24
# | 에폭 7 |  반복 1 / 999 | 시간 313[s] | 손실 2.25
# | 에폭 7 |  반복 21 / 999 | 시간 314[s] | 손실 2.14
# | 에폭 7 |  반복 41 / 999 | 시간 315[s] | 손실 2.16
# | 에폭 7 |  반복 61 / 999 | 시간 316[s] | 손실 2.14
# | 에폭 7 |  반복 81 / 999 | 시간 317[s] | 손실 2.16
# | 에폭 7 |  반복 101 / 999 | 시간 318[s] | 손실 2.16
# | 에폭 7 |  반복 121 / 999 | 시간 319[s] | 손실 2.14
# | 에폭 7 |  반복 141 / 999 | 시간 320[s] | 손실 2.18
# | 에폭 7 |  반복 161 / 999 | 시간 321[s] | 손실 2.17
# | 에폭 7 |  반복 181 / 999 | 시간 322[s] | 손실 2.18
# | 에폭 7 |  반복 201 / 999 | 시간 323[s] | 손실 2.16
# | 에폭 7 |  반복 221 / 999 | 시간 324[s] | 손실 2.20
# | 에폭 7 |  반복 241 / 999 | 시간 325[s] | 손실 2.17
# | 에폭 7 |  반복 261 / 999 | 시간 326[s] | 손실 2.17
# | 에폭 7 |  반복 281 / 999 | 시간 328[s] | 손실 2.17
# | 에폭 7 |  반복 301 / 999 | 시간 329[s] | 손실 2.16
# | 에폭 7 |  반복 321 / 999 | 시간 330[s] | 손실 2.19
# | 에폭 7 |  반복 341 / 999 | 시간 331[s] | 손실 2.19
# | 에폭 7 |  반복 361 / 999 | 시간 332[s] | 손실 2.19
# | 에폭 7 |  반복 381 / 999 | 시간 333[s] | 손실 2.20
# | 에폭 7 |  반복 401 / 999 | 시간 334[s] | 손실 2.19
# | 에폭 7 |  반복 421 / 999 | 시간 335[s] | 손실 2.18
# | 에폭 7 |  반복 441 / 999 | 시간 336[s] | 손실 2.14
# | 에폭 7 |  반복 461 / 999 | 시간 337[s] | 손실 2.14
# | 에폭 7 |  반복 481 / 999 | 시간 338[s] | 손실 2.16
# | 에폭 7 |  반복 501 / 999 | 시간 339[s] | 손실 2.18
# | 에폭 7 |  반복 521 / 999 | 시간 340[s] | 손실 2.14
# | 에폭 7 |  반복 541 / 999 | 시간 341[s] | 손실 2.16
# | 에폭 7 |  반복 561 / 999 | 시간 342[s] | 손실 2.15
# | 에폭 7 |  반복 581 / 999 | 시간 343[s] | 손실 2.19
# | 에폭 7 |  반복 601 / 999 | 시간 344[s] | 손실 2.17
# | 에폭 7 |  반복 621 / 999 | 시간 345[s] | 손실 2.18
# | 에폭 7 |  반복 641 / 999 | 시간 346[s] | 손실 2.16
# | 에폭 7 |  반복 661 / 999 | 시간 347[s] | 손실 2.13
# | 에폭 7 |  반복 681 / 999 | 시간 348[s] | 손실 2.16
# | 에폭 7 |  반복 701 / 999 | 시간 349[s] | 손실 2.18
# | 에폭 7 |  반복 721 / 999 | 시간 350[s] | 손실 2.16
# | 에폭 7 |  반복 741 / 999 | 시간 352[s] | 손실 2.11
# | 에폭 7 |  반복 761 / 999 | 시간 353[s] | 손실 2.15
# | 에폭 7 |  반복 781 / 999 | 시간 354[s] | 손실 2.13
# | 에폭 7 |  반복 801 / 999 | 시간 355[s] | 손실 2.20
# | 에폭 7 |  반복 821 / 999 | 시간 356[s] | 손실 2.18
# | 에폭 7 |  반복 841 / 999 | 시간 357[s] | 손실 2.14
# | 에폭 7 |  반복 861 / 999 | 시간 358[s] | 손실 2.17
# | 에폭 7 |  반복 881 / 999 | 시간 359[s] | 손실 2.15
# | 에폭 7 |  반복 901 / 999 | 시간 360[s] | 손실 2.15
# | 에폭 7 |  반복 921 / 999 | 시간 361[s] | 손실 2.17
# | 에폭 7 |  반복 941 / 999 | 시간 362[s] | 손실 2.18
# | 에폭 7 |  반복 961 / 999 | 시간 363[s] | 손실 2.14
# | 에폭 7 |  반복 981 / 999 | 시간 364[s] | 손실 2.15
# | 에폭 8 |  반복 1 / 999 | 시간 365[s] | 손실 2.15
# | 에폭 8 |  반복 21 / 999 | 시간 366[s] | 손실 2.08
# | 에폭 8 |  반복 41 / 999 | 시간 367[s] | 손실 2.09
# | 에폭 8 |  반복 61 / 999 | 시간 368[s] | 손실 2.07
# | 에폭 8 |  반복 81 / 999 | 시간 369[s] | 손실 2.06
# | 에폭 8 |  반복 101 / 999 | 시간 370[s] | 손실 2.08
# | 에폭 8 |  반복 121 / 999 | 시간 371[s] | 손실 2.08
# | 에폭 8 |  반복 141 / 999 | 시간 372[s] | 손실 2.07
# | 에폭 8 |  반복 161 / 999 | 시간 373[s] | 손실 2.11
# | 에폭 8 |  반복 181 / 999 | 시간 374[s] | 손실 2.08
# | 에폭 8 |  반복 201 / 999 | 시간 375[s] | 손실 2.08
# | 에폭 8 |  반복 221 / 999 | 시간 376[s] | 손실 2.08
# | 에폭 8 |  반복 241 / 999 | 시간 377[s] | 손실 2.07
# | 에폭 8 |  반복 261 / 999 | 시간 378[s] | 손실 2.05
# | 에폭 8 |  반복 281 / 999 | 시간 379[s] | 손실 2.08
# | 에폭 8 |  반복 301 / 999 | 시간 381[s] | 손실 2.10
# | 에폭 8 |  반복 321 / 999 | 시간 382[s] | 손실 2.11
# | 에폭 8 |  반복 341 / 999 | 시간 383[s] | 손실 2.09
# | 에폭 8 |  반복 361 / 999 | 시간 384[s] | 손실 2.11
# | 에폭 8 |  반복 381 / 999 | 시간 385[s] | 손실 2.08
# | 에폭 8 |  반복 401 / 999 | 시간 386[s] | 손실 2.09
# | 에폭 8 |  반복 421 / 999 | 시간 387[s] | 손실 2.09
# | 에폭 8 |  반복 441 / 999 | 시간 388[s] | 손실 2.09
# | 에폭 8 |  반복 461 / 999 | 시간 389[s] | 손실 2.10
# | 에폭 8 |  반복 481 / 999 | 시간 390[s] | 손실 2.12
# | 에폭 8 |  반복 501 / 999 | 시간 391[s] | 손실 2.10
# | 에폭 8 |  반복 521 / 999 | 시간 392[s] | 손실 2.10
# | 에폭 8 |  반복 541 / 999 | 시간 393[s] | 손실 2.07
# | 에폭 8 |  반복 561 / 999 | 시간 394[s] | 손실 2.07
# | 에폭 8 |  반복 581 / 999 | 시간 395[s] | 손실 2.08
# | 에폭 8 |  반복 601 / 999 | 시간 396[s] | 손실 2.08
# | 에폭 8 |  반복 621 / 999 | 시간 397[s] | 손실 2.10
# | 에폭 8 |  반복 641 / 999 | 시간 398[s] | 손실 2.06
# | 에폭 8 |  반복 661 / 999 | 시간 399[s] | 손실 2.05
# | 에폭 8 |  반복 681 / 999 | 시간 400[s] | 손실 2.11
# | 에폭 8 |  반복 701 / 999 | 시간 401[s] | 손실 2.09
# | 에폭 8 |  반복 721 / 999 | 시간 402[s] | 손실 2.08
# | 에폭 8 |  반복 741 / 999 | 시간 403[s] | 손실 2.06
# | 에폭 8 |  반복 761 / 999 | 시간 404[s] | 손실 2.12
# | 에폭 8 |  반복 781 / 999 | 시간 405[s] | 손실 2.07
# | 에폭 8 |  반복 801 / 999 | 시간 406[s] | 손실 2.09
# | 에폭 8 |  반복 821 / 999 | 시간 407[s] | 손실 2.08
# | 에폭 8 |  반복 841 / 999 | 시간 409[s] | 손실 2.11
# | 에폭 8 |  반복 861 / 999 | 시간 410[s] | 손실 2.05
# | 에폭 8 |  반복 881 / 999 | 시간 411[s] | 손실 2.10
# | 에폭 8 |  반복 901 / 999 | 시간 412[s] | 손실 2.07
# | 에폭 8 |  반복 921 / 999 | 시간 413[s] | 손실 2.05
# | 에폭 8 |  반복 941 / 999 | 시간 414[s] | 손실 2.07
# | 에폭 8 |  반복 961 / 999 | 시간 415[s] | 손실 2.09
# | 에폭 8 |  반복 981 / 999 | 시간 416[s] | 손실 2.07
# | 에폭 9 |  반복 1 / 999 | 시간 417[s] | 손실 2.08
# | 에폭 9 |  반복 21 / 999 | 시간 418[s] | 손실 2.03
# | 에폭 9 |  반복 41 / 999 | 시간 419[s] | 손실 2.01
# | 에폭 9 |  반복 61 / 999 | 시간 420[s] | 손실 2.00
# | 에폭 9 |  반복 81 / 999 | 시간 421[s] | 손실 2.01
# | 에폭 9 |  반복 101 / 999 | 시간 422[s] | 손실 1.98
# | 에폭 9 |  반복 121 / 999 | 시간 423[s] | 손실 2.00
# | 에폭 9 |  반복 141 / 999 | 시간 424[s] | 손실 2.02
# | 에폭 9 |  반복 161 / 999 | 시간 425[s] | 손실 1.99
# | 에폭 9 |  반복 181 / 999 | 시간 426[s] | 손실 2.01
# | 에폭 9 |  반복 201 / 999 | 시간 427[s] | 손실 1.97
# | 에폭 9 |  반복 221 / 999 | 시간 428[s] | 손실 1.98
# | 에폭 9 |  반복 241 / 999 | 시간 429[s] | 손실 2.00
# | 에폭 9 |  반복 261 / 999 | 시간 430[s] | 손실 2.01
# | 에폭 9 |  반복 281 / 999 | 시간 431[s] | 손실 1.99
# | 에폭 9 |  반복 301 / 999 | 시간 432[s] | 손실 2.02
# | 에폭 9 |  반복 321 / 999 | 시간 433[s] | 손실 2.01
# | 에폭 9 |  반복 341 / 999 | 시간 434[s] | 손실 2.02
# | 에폭 9 |  반복 361 / 999 | 시간 435[s] | 손실 2.02
# | 에폭 9 |  반복 381 / 999 | 시간 436[s] | 손실 1.99
# | 에폭 9 |  반복 401 / 999 | 시간 437[s] | 손실 1.99
# | 에폭 9 |  반복 421 / 999 | 시간 439[s] | 손실 2.01
# | 에폭 9 |  반복 441 / 999 | 시간 440[s] | 손실 2.01
# | 에폭 9 |  반복 461 / 999 | 시간 441[s] | 손실 2.03
# | 에폭 9 |  반복 481 / 999 | 시간 442[s] | 손실 1.99
# | 에폭 9 |  반복 501 / 999 | 시간 443[s] | 손실 2.00
# | 에폭 9 |  반복 521 / 999 | 시간 444[s] | 손실 1.98
# | 에폭 9 |  반복 541 / 999 | 시간 445[s] | 손실 2.00
# | 에폭 9 |  반복 561 / 999 | 시간 446[s] | 손실 2.02
# | 에폭 9 |  반복 581 / 999 | 시간 447[s] | 손실 2.00
# | 에폭 9 |  반복 601 / 999 | 시간 448[s] | 손실 2.01
# | 에폭 9 |  반복 621 / 999 | 시간 449[s] | 손실 2.02
# | 에폭 9 |  반복 641 / 999 | 시간 450[s] | 손실 2.00
# | 에폭 9 |  반복 661 / 999 | 시간 451[s] | 손실 2.02
# | 에폭 9 |  반복 681 / 999 | 시간 452[s] | 손실 2.01
# | 에폭 9 |  반복 701 / 999 | 시간 453[s] | 손실 2.01
# | 에폭 9 |  반복 721 / 999 | 시간 454[s] | 손실 2.01
# | 에폭 9 |  반복 741 / 999 | 시간 455[s] | 손실 2.02
# | 에폭 9 |  반복 761 / 999 | 시간 456[s] | 손실 2.02
# | 에폭 9 |  반복 781 / 999 | 시간 457[s] | 손실 2.01
# | 에폭 9 |  반복 801 / 999 | 시간 458[s] | 손실 2.00
# | 에폭 9 |  반복 821 / 999 | 시간 459[s] | 손실 2.01
# | 에폭 9 |  반복 841 / 999 | 시간 460[s] | 손실 2.02
# | 에폭 9 |  반복 861 / 999 | 시간 461[s] | 손실 2.01
# | 에폭 9 |  반복 881 / 999 | 시간 462[s] | 손실 2.01
# | 에폭 9 |  반복 901 / 999 | 시간 464[s] | 손실 2.02
# | 에폭 9 |  반복 921 / 999 | 시간 465[s] | 손실 2.02
# | 에폭 9 |  반복 941 / 999 | 시간 466[s] | 손실 2.00
# | 에폭 9 |  반복 961 / 999 | 시간 467[s] | 손실 1.99
# | 에폭 9 |  반복 981 / 999 | 시간 468[s] | 손실 2.01
# | 에폭 10 |  반복 1 / 999 | 시간 469[s] | 손실 2.03
# | 에폭 10 |  반복 21 / 999 | 시간 470[s] | 손실 1.92
# | 에폭 10 |  반복 41 / 999 | 시간 471[s] | 손실 1.94
# | 에폭 10 |  반복 61 / 999 | 시간 472[s] | 손실 1.94
# | 에폭 10 |  반복 81 / 999 | 시간 473[s] | 손실 1.93
# | 에폭 10 |  반복 101 / 999 | 시간 474[s] | 손실 1.94
# | 에폭 10 |  반복 121 / 999 | 시간 475[s] | 손실 1.93
# | 에폭 10 |  반복 141 / 999 | 시간 476[s] | 손실 1.95
# | 에폭 10 |  반복 161 / 999 | 시간 477[s] | 손실 1.92
# | 에폭 10 |  반복 181 / 999 | 시간 478[s] | 손실 1.92
# | 에폭 10 |  반복 201 / 999 | 시간 479[s] | 손실 1.92
# | 에폭 10 |  반복 221 / 999 | 시간 480[s] | 손실 1.95
# | 에폭 10 |  반복 241 / 999 | 시간 481[s] | 손실 1.92
# | 에폭 10 |  반복 261 / 999 | 시간 482[s] | 손실 1.93
# | 에폭 10 |  반복 281 / 999 | 시간 483[s] | 손실 1.94
# | 에폭 10 |  반복 301 / 999 | 시간 484[s] | 손실 1.94
# | 에폭 10 |  반복 321 / 999 | 시간 485[s] | 손실 1.91
# | 에폭 10 |  반복 341 / 999 | 시간 486[s] | 손실 1.92
# | 에폭 10 |  반복 361 / 999 | 시간 487[s] | 손실 1.92
# | 에폭 10 |  반복 381 / 999 | 시간 488[s] | 손실 1.94
# | 에폭 10 |  반복 401 / 999 | 시간 489[s] | 손실 1.95
# | 에폭 10 |  반복 421 / 999 | 시간 490[s] | 손실 1.94
# | 에폭 10 |  반복 441 / 999 | 시간 492[s] | 손실 1.94
# | 에폭 10 |  반복 461 / 999 | 시간 493[s] | 손실 1.92
# | 에폭 10 |  반복 481 / 999 | 시간 494[s] | 손실 1.93
# | 에폭 10 |  반복 501 / 999 | 시간 495[s] | 손실 1.94
# | 에폭 10 |  반복 521 / 999 | 시간 496[s] | 손실 1.92
# | 에폭 10 |  반복 541 / 999 | 시간 497[s] | 손실 1.93
# | 에폭 10 |  반복 561 / 999 | 시간 498[s] | 손실 1.93
# | 에폭 10 |  반복 581 / 999 | 시간 499[s] | 손실 1.93
# | 에폭 10 |  반복 601 / 999 | 시간 500[s] | 손실 1.92
# | 에폭 10 |  반복 621 / 999 | 시간 501[s] | 손실 1.90
# | 에폭 10 |  반복 641 / 999 | 시간 502[s] | 손실 1.95
# | 에폭 10 |  반복 661 / 999 | 시간 503[s] | 손실 1.93
# | 에폭 10 |  반복 681 / 999 | 시간 504[s] | 손실 1.93
# | 에폭 10 |  반복 701 / 999 | 시간 505[s] | 손실 1.96
# | 에폭 10 |  반복 721 / 999 | 시간 506[s] | 손실 1.94
# | 에폭 10 |  반복 741 / 999 | 시간 507[s] | 손실 1.93
# | 에폭 10 |  반복 761 / 999 | 시간 508[s] | 손실 1.95
# | 에폭 10 |  반복 781 / 999 | 시간 509[s] | 손실 1.93
# | 에폭 10 |  반복 801 / 999 | 시간 510[s] | 손실 1.94
# | 에폭 10 |  반복 821 / 999 | 시간 511[s] | 손실 1.92
# | 에폭 10 |  반복 841 / 999 | 시간 512[s] | 손실 1.94
# | 에폭 10 |  반복 861 / 999 | 시간 513[s] | 손실 1.94
# | 에폭 10 |  반복 881 / 999 | 시간 514[s] | 손실 1.91
# | 에폭 10 |  반복 901 / 999 | 시간 515[s] | 손실 1.91
# | 에폭 10 |  반복 921 / 999 | 시간 516[s] | 손실 1.93
# | 에폭 10 |  반복 941 / 999 | 시간 517[s] | 손실 1.93
# | 에폭 10 |  반복 961 / 999 | 시간 519[s] | 손실 1.94
# | 에폭 10 |  반복 981 / 999 | 시간 520[s] | 손실 1.92

# %% [markdown]
# ###  CBOW 모델 평가

# %%
pkl_file = 'cbow_params.pkl'
# pkl_file = 'cbow_params_epoch10.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# 가장 비슷한(most similar) 단어 뽑기
querys = ['you', 'year', 'car']
# querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875

# %%
def normalize(x):
    if x.ndim == 2:
        s = np.sqrt((x * x).sum(1))
        x /= s.reshape((s.shape[0], 1))
    elif x.ndim == 1:
        s = np.sqrt((x * x).sum())
        x /= s
    return x

def analogy(a, b, c, word_to_id, id_to_word, word_matrix, top=5, answer=None):
    for word in (a, b, c):
        if word not in word_to_id:
            print('%s(을)를 찾을 수 없습니다.' % word)
            return

    print('\n[analogy] ' + a + ':' + b + ' = ' + c + ':?')
    a_vec, b_vec, c_vec = word_matrix[word_to_id[a]], word_matrix[word_to_id[b]], word_matrix[word_to_id[c]]
    query_vec = b_vec - a_vec + c_vec
    query_vec = normalize(query_vec)

    similarity = np.dot(word_matrix, query_vec)

    if answer is not None:
        print("==>" + answer + ":" + str(np.dot(word_matrix[word_to_id[answer]], query_vec)))

    count = 0
    for i in (-1 * similarity).argsort():
        if np.isnan(similarity[i]):
            continue
        if id_to_word[i] in (a, b, c):
            continue
        print(' {0}: {1}'.format(id_to_word[i], similarity[i]))

        count += 1
        if count >= top:
            return

# %%
# 유추(analogy) 작업
# analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
# analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# [analogy] king:man = queen:?
#  woman: 5.16015625
#  veto: 4.9296875
#  ounce: 4.69140625
#  earthquake: 4.6328125
#  successor: 4.609375
#
# [analogy] take:took = go:?
#  went: 4.55078125
#  points: 4.25
#  began: 4.09375
#  comes: 3.98046875
#  oct.: 3.90625
#
# [analogy] car:cars = child:?
#  children: 5.21875
#  average: 4.7265625
#  yield: 4.20703125
#  cattle: 4.1875
#  priced: 4.1796875
#
# [analogy] good:better = bad:?
#  more: 6.6484375
#  less: 6.0625
#  rather: 5.21875
#  slower: 4.734375
#  greater: 4.671875

# %% [markdown]
# ### SkipGram 모델 구현

# %%
class SkipGram:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        W_in = 0.01 * rn(V, H).astype('f')
        W_out = 0.01 * rn(V, H).astype('f')

        # 계층 생성
        self.in_layer = Embedding(W_in)
        self.loss_layers = []
        for i in range(2 * window_size):
            layer = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)
            self.loss_layers.append(layer)

        # 모든 가중치와 기울기를 리스트에 모은다.
        layers = [self.in_layer] + self.loss_layers
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = self.in_layer.forward(target)

        loss = 0
        for i, layer in enumerate(self.loss_layers):
            loss += layer.forward(h, contexts[:, i])
        return loss

    def backward(self, dout=1):
        dh = 0
        for i, layer in enumerate(self.loss_layers):
            dh += layer.backward(dout)
        self.in_layer.backward(dh)
        return None

# %% [markdown]
# ### SkipGram 모델 학습 코드

# %%
from dataset import ptb
import pickle

# 하이퍼파라미터 설정
window_size = 5
# window_size = 2

hidden_size = 100
batch_size = 100
max_epoch = 10  # 10회 이상

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')

# %%
# PTB 데이터 중 일부만 사용시
corpus, word_to_id, id_to_word = ptb.load_data('train')

corpus_size = 10000
corpus = corpus[:corpus_size]

vocab_size = int(max(corpus) + 1)

temp1,temp2 = {},{}
for k in range(vocab_size):
    word1= list(word_to_id.keys())[k]    
    id1 = list(word_to_id.values())[k] 
    temp1[word1] = id1
    
    word2= list(id_to_word.keys())[k]    
    id2 = list(id_to_word.values())[k] 
    temp2[word2] = id2
    
word_to_id = temp1
id_to_word =temp2

print(len(corpus))
print(vocab_size)
print(len(word_to_id))
print(len(id_to_word))
# Out:
# 10000
# 2138
# 2138
# 2138

# %%
vocab_size = len(word_to_id)


contexts, target = create_contexts_target(corpus, window_size)
# if config.GPU:
#     contexts, target = to_gpu(contexts), to_gpu(target)

# 모델 등 생성
# model = CBOW(vocab_size, hidden_size, window_size, corpus)
model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs

params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 99 | 시간 0[s] | 손실 41.59
# | 에폭 1 |  반복 21 / 99 | 시간 3[s] | 손실 41.57
# | 에폭 1 |  반복 41 / 99 | 시간 6[s] | 손실 41.35
# | 에폭 1 |  반복 61 / 99 | 시간 10[s] | 손실 40.49
# | 에폭 1 |  반복 81 / 99 | 시간 13[s] | 손실 38.72
# | 에폭 2 |  반복 1 / 99 | 시간 16[s] | 손실 36.49
# | 에폭 2 |  반복 21 / 99 | 시간 19[s] | 손실 34.43
# | 에폭 2 |  반복 41 / 99 | 시간 23[s] | 손실 33.07
# | 에폭 2 |  반복 61 / 99 | 시간 26[s] | 손실 31.89
# | 에폭 2 |  반복 81 / 99 | 시간 29[s] | 손실 31.30
# | 에폭 3 |  반복 1 / 99 | 시간 33[s] | 손실 30.41
# | 에폭 3 |  반복 21 / 99 | 시간 36[s] | 손실 29.74
# | 에폭 3 |  반복 41 / 99 | 시간 39[s] | 손실 29.33
# | 에폭 3 |  반복 61 / 99 | 시간 43[s] | 손실 29.04
# | 에폭 3 |  반복 81 / 99 | 시간 46[s] | 손실 28.78
# | 에폭 4 |  반복 1 / 99 | 시간 49[s] | 손실 28.79
# | 에폭 4 |  반복 21 / 99 | 시간 53[s] | 손실 27.94
# | 에폭 4 |  반복 41 / 99 | 시간 56[s] | 손실 27.71
# | 에폭 4 |  반복 61 / 99 | 시간 60[s] | 손실 27.71
# | 에폭 4 |  반복 81 / 99 | 시간 63[s] | 손실 27.79
# | 에폭 5 |  반복 1 / 99 | 시간 66[s] | 손실 27.57
# | 에폭 5 |  반복 21 / 99 | 시간 70[s] | 손실 27.10
# | 에폭 5 |  반복 41 / 99 | 시간 73[s] | 손실 26.95
# | 에폭 5 |  반복 61 / 99 | 시간 76[s] | 손실 26.98
# | 에폭 5 |  반복 81 / 99 | 시간 80[s] | 손실 26.90
# | 에폭 6 |  반복 1 / 99 | 시간 83[s] | 손실 26.76
# | 에폭 6 |  반복 21 / 99 | 시간 86[s] | 손실 26.57
# | 에폭 6 |  반복 41 / 99 | 시간 90[s] | 손실 26.47
# | 에폭 6 |  반복 61 / 99 | 시간 93[s] | 손실 26.44
# | 에폭 6 |  반복 81 / 99 | 시간 96[s] | 손실 26.37
# | 에폭 7 |  반복 1 / 99 | 시간 100[s] | 손실 26.43
# | 에폭 7 |  반복 21 / 99 | 시간 103[s] | 손실 26.06
# | 에폭 7 |  반복 41 / 99 | 시간 106[s] | 손실 26.07
# | 에폭 7 |  반복 61 / 99 | 시간 110[s] | 손실 26.17
# | 에폭 7 |  반복 81 / 99 | 시간 113[s] | 손실 26.16
# | 에폭 8 |  반복 1 / 99 | 시간 116[s] | 손실 26.12
# | 에폭 8 |  반복 21 / 99 | 시간 119[s] | 손실 25.90
# | 에폭 8 |  반복 41 / 99 | 시간 123[s] | 손실 25.84
# | 에폭 8 |  반복 61 / 99 | 시간 126[s] | 손실 25.91
# | 에폭 8 |  반복 81 / 99 | 시간 130[s] | 손실 25.88
# | 에폭 9 |  반복 1 / 99 | 시간 133[s] | 손실 25.96
# | 에폭 9 |  반복 21 / 99 | 시간 136[s] | 손실 25.76
# | 에폭 9 |  반복 41 / 99 | 시간 140[s] | 손실 25.68
# | 에폭 9 |  반복 61 / 99 | 시간 143[s] | 손실 25.75
# | 에폭 9 |  반복 81 / 99 | 시간 147[s] | 손실 25.69
# | 에폭 10 |  반복 1 / 99 | 시간 150[s] | 손실 25.75
# | 에폭 10 |  반복 21 / 99 | 시간 153[s] | 손실 25.66
# | 에폭 10 |  반복 41 / 99 | 시간 157[s] | 손실 25.51
# | 에폭 10 |  반복 61 / 99 | 시간 160[s] | 손실 25.66
# | 에폭 10 |  반복 81 / 99 | 시간 164[s] | 손실 25.59

# %%
pkl_file = 'skipgram_params.pkl'
# pkl_file = 'skipgram_params_epoch_10.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# 가장 비슷한(most similar) 단어 뽑기
querys = ['you', 'year']
# querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  seymour: 0.98828125
#  argue: 0.98779296875
#  too: 0.98779296875
#  come: 0.9873046875
#  team: 0.98681640625
#
# [query] year
#  last: 0.96435546875
#  share: 0.96044921875
#  up: 0.95947265625
#  down: 0.9560546875
#  annual: 0.951171875
